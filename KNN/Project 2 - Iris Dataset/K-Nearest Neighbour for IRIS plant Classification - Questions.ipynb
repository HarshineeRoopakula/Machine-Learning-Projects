# %% [markdown]
# ## Project Name: Iris Plant Classification using KNN

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant. The attribute to be predicted is the class of iris plant. The classes are as follows: 1. Iris Setosa, 2. Iris Versicolour, 3. Iris Virginica
#
# There are 4 features:
# 1. sepalLength: sepal length in cm
# 2. sepalWidth: sepal width in cm
# 3. petalLength: petal length in cm
# 4. petalWidth: petal width in cm
#
# There are 3 classes representing class label of iris flower {1,2,3}
# 1. Iris Setosa
# 2. Iris Versicolour
# 3. Iris Virginica
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing the Dataset

# %%
iris=pd.read_csv("Iris.csv")

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
sns.scatterplot(x=iris["SepalLengthCm"],y=iris["SepalWidthCm"],hue=iris["Species"])
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.scatterplot(x=iris["PetalLengthCm"],y=iris["PetalWidthCm"],hue=iris["Species"])
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
plt.figure(figsize=(10,8))

plt.subplot(2,2,1)
sns.violinplot(y=iris["PetalLengthCm"],x=iris["Species"])

plt.subplot(2,2,2)
sns.violinplot(y=iris["PetalWidthCm"],x=iris["Species"])

plt.subplot(2,2,3)
sns.violinplot(y=iris["SepalLengthCm"],x=iris["Species"])

plt.subplot(2,2,4)
sns.violinplot(y=iris["SepalWidthCm"],x=iris["Species"])
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.pairplot(data=iris,hue="Species",vars=["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"])

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data=iris.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Data Cleaning

# %%
X=iris.drop("Species",axis=1)

# %%
y=iris["Species"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=5)

# %%
X_train.shape
# Out:
# (112, 4)

# %% [markdown]
# ## Training the model

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier(n_neighbors=6)

# %%
knn_model.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 6,
#  'p': 2,
#  'weights': 'uniform'}

# %%
knn_model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %% [markdown]
# ## Evaluating the model

# %%
y_pred=knn_model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
cm = confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        12
# Iris-versicolor       0.93      1.00      0.97        14
#  Iris-virginica       1.00      0.92      0.96        12
#
#        accuracy                           0.97        38
#       macro avg       0.98      0.97      0.97        38
#    weighted avg       0.98      0.97      0.97        38

# %% [markdown]
# # EXCELLENT JOB! NOW YOU BECAME EXPERT IN K-NEAREST NEIGHBORS, KEEP UP THE GOOD WORK!
