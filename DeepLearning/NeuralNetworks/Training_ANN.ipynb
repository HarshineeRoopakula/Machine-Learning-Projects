# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshineeRoopakula/Machine-Learning/blob/main/DeepLearning/NeuralNetworks/Training_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense

# Define Training DATA i.e, ANN Gate Inputs
input = np.array([[0,0],[0,1],[1,0],[1,1]])
# Desired Output
output = np.array([[1],[0],[1],[0]])

# Model Definition
model = Sequential()
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='mean_squared_error',optimizer='adam', metrics=['binary_accuracy'])

# Train Model
model.fit(input, output, epochs=600, verbose=2)

# Validation
print("Round off Values: \n",model.predict(input).round())
print("Actual Values: \n",model.predict(input))
# Out:
# Epoch 1/600
# 1/1 - 1s - loss: 0.3031 - binary_accuracy: 0.2500
# Epoch 2/600
# 1/1 - 0s - loss: 0.3018 - binary_accuracy: 0.2500
# Epoch 3/600
# 1/1 - 0s - loss: 0.3006 - binary_accuracy: 0.2500
# Epoch 4/600
# 1/1 - 0s - loss: 0.2993 - binary_accuracy: 0.2500
# Epoch 5/600
# 1/1 - 0s - loss: 0.2981 - binary_accuracy: 0.2500
# Epoch 6/600
# 1/1 - 0s - loss: 0.2968 - binary_accuracy: 0.2500
# Epoch 7/600
# 1/1 - 0s - loss: 0.2956 - binary_accuracy: 0.2500
# Epoch 8/600
# 1/1 - 0s - loss: 0.2944 - binary_accuracy: 0.2500
# Epoch 9/600
# 1/1 - 0s - loss: 0.2931 - binary_accuracy: 0.2500
# Epoch 10/600
# 1/1 - 0s - loss: 0.2919 - binary_accuracy: 0.2500
# Epoch 11/600
# 1/1 - 0s - loss: 0.2907 - binary_accuracy: 0.2500
# Epoch 12/600
# 1/1 - 0s - loss: 0.2895 - binary_accuracy: 0.2500
# Epoch 13/600
# 1/1 - 0s - loss: 0.2883 - binary_accuracy: 0.2500
# Epoch 14/600
# 1/1 - 0s - loss: 0.2871 - binary_accuracy: 0.2500
# Epoch 15/600
# 1/1 - 0s - loss: 0.2859 - binary_accuracy: 0.2500
# ...
