# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshineeRoopakula/Machine-Learning/blob/main/DeepLearning/NeuralNetworks/OR_NeuralNetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense

# Define Training DATA i.e, OR Gate Inputs
input = np.array([[0,0],[0,1],[1,0],[1,1]])
# Desired Output
output = np.array([[0],[1],[1],[1]])

# Model Definition
model = Sequential()
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='mean_squared_error',optimizer='adam', metrics=['binary_accuracy'])

# Train Model
model.fit(input, output, epochs=600, verbose=2)

# Validation
print("Round off Values: \n",model.predict(input).round())
print("Actual Values: \n",model.predict(input))
# Out:
# Epoch 1/600
# 1/1 - 14s - loss: 0.1925 - binary_accuracy: 1.0000
# Epoch 2/600
# 1/1 - 0s - loss: 0.1914 - binary_accuracy: 0.7500
# Epoch 3/600
# 1/1 - 0s - loss: 0.1904 - binary_accuracy: 0.7500
# Epoch 4/600
# 1/1 - 0s - loss: 0.1894 - binary_accuracy: 0.7500
# Epoch 5/600
# 1/1 - 0s - loss: 0.1883 - binary_accuracy: 0.7500
# Epoch 6/600
# 1/1 - 0s - loss: 0.1873 - binary_accuracy: 0.7500
# Epoch 7/600
# 1/1 - 0s - loss: 0.1863 - binary_accuracy: 0.7500
# Epoch 8/600
# 1/1 - 0s - loss: 0.1853 - binary_accuracy: 0.7500
# Epoch 9/600
# 1/1 - 0s - loss: 0.1843 - binary_accuracy: 0.7500
# Epoch 10/600
# 1/1 - 0s - loss: 0.1833 - binary_accuracy: 0.7500
# Epoch 11/600
# 1/1 - 0s - loss: 0.1823 - binary_accuracy: 0.7500
# Epoch 12/600
# 1/1 - 0s - loss: 0.1813 - binary_accuracy: 0.7500
# Epoch 13/600
# 1/1 - 0s - loss: 0.1803 - binary_accuracy: 0.7500
# Epoch 14/600
# 1/1 - 0s - loss: 0.1794 - binary_accuracy: 0.7500
# Epoch 15/600
# 1/1 - 0s - loss: 0.1784 - binary_accuracy: 0.7500
# ...
