# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshineeRoopakula/Machine-Learning/blob/main/DeepLearning/NeuralNetworks/AND_NeuralNetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense

# Define Training DATA i.e, AND Gate Inputs
input = np.array([[0,0],[0,1],[1,0],[1,1]])
# Desired Output
output = np.array([[0],[0],[0],[1]])

# Model Definition
model = Sequential()
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='mean_squared_error',optimizer='adam', metrics=['binary_accuracy'])

# Train Model
model.fit(input, output, epochs=600, verbose=2)

# Validation
print("Round off Values: \n",model.predict(input).round())
print("Actual Values: \n",model.predict(input))
# Out:
# Epoch 1/600
# 1/1 - 15s - loss: 0.2540 - binary_accuracy: 0.7500
# Epoch 2/600
# 1/1 - 0s - loss: 0.2536 - binary_accuracy: 0.7500
# Epoch 3/600
# 1/1 - 0s - loss: 0.2531 - binary_accuracy: 0.7500
# Epoch 4/600
# 1/1 - 0s - loss: 0.2526 - binary_accuracy: 0.7500
# Epoch 5/600
# 1/1 - 0s - loss: 0.2521 - binary_accuracy: 0.7500
# Epoch 6/600
# 1/1 - 0s - loss: 0.2516 - binary_accuracy: 0.7500
# Epoch 7/600
# 1/1 - 0s - loss: 0.2512 - binary_accuracy: 0.7500
# Epoch 8/600
# 1/1 - 0s - loss: 0.2507 - binary_accuracy: 0.7500
# Epoch 9/600
# 1/1 - 0s - loss: 0.2502 - binary_accuracy: 0.7500
# Epoch 10/600
# 1/1 - 0s - loss: 0.2497 - binary_accuracy: 0.7500
# Epoch 11/600
# 1/1 - 0s - loss: 0.2493 - binary_accuracy: 0.7500
# Epoch 12/600
# 1/1 - 0s - loss: 0.2488 - binary_accuracy: 0.7500
# Epoch 13/600
# 1/1 - 0s - loss: 0.2483 - binary_accuracy: 0.7500
# Epoch 14/600
# 1/1 - 0s - loss: 0.2479 - binary_accuracy: 0.7500
# Epoch 15/600
# 1/1 - 0s - loss: 0.2474 - binary_accuracy: 0.7500
# ...
