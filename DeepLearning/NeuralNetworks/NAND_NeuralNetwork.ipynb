# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshineeRoopakula/Machine-Learning/blob/main/DeepLearning/NeuralNetworks/NAND_NeuralNetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense

# Define Training DATA i.e, NAND Gate Inputs
input = np.array([[0,0],[0,1],[1,0],[1,1]])
# Desired Output
output = np.array([[1],[1],[1],[0]])

# Model Definition
model = Sequential()
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='mean_squared_error',optimizer='adam', metrics=['binary_accuracy'])

# Train Model
model.fit(input, output, epochs=600, verbose=2)

# Validation
print("Round off Values: \n",model.predict(input).round())
print("Actual Values: \n",model.predict(input))
# Out:
# Epoch 1/600
# 1/1 - 13s - loss: 0.2307 - binary_accuracy: 0.7500
# Epoch 2/600
# 1/1 - 0s - loss: 0.2301 - binary_accuracy: 1.0000
# Epoch 3/600
# 1/1 - 0s - loss: 0.2294 - binary_accuracy: 1.0000
# Epoch 4/600
# 1/1 - 0s - loss: 0.2287 - binary_accuracy: 1.0000
# Epoch 5/600
# 1/1 - 0s - loss: 0.2280 - binary_accuracy: 1.0000
# Epoch 6/600
# 1/1 - 0s - loss: 0.2274 - binary_accuracy: 1.0000
# Epoch 7/600
# 1/1 - 0s - loss: 0.2267 - binary_accuracy: 1.0000
# Epoch 8/600
# 1/1 - 0s - loss: 0.2260 - binary_accuracy: 1.0000
# Epoch 9/600
# 1/1 - 0s - loss: 0.2253 - binary_accuracy: 1.0000
# Epoch 10/600
# 1/1 - 0s - loss: 0.2247 - binary_accuracy: 1.0000
# Epoch 11/600
# 1/1 - 0s - loss: 0.2240 - binary_accuracy: 1.0000
# Epoch 12/600
# 1/1 - 0s - loss: 0.2233 - binary_accuracy: 1.0000
# Epoch 13/600
# 1/1 - 0s - loss: 0.2227 - binary_accuracy: 1.0000
# Epoch 14/600
# 1/1 - 0s - loss: 0.2220 - binary_accuracy: 1.0000
# Epoch 15/600
# 1/1 - 0s - loss: 0.2213 - binary_accuracy: 1.0000
# ...
