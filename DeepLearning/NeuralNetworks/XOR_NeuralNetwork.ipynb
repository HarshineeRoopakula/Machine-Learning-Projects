# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshineeRoopakula/Machine-Learning/blob/main/DeepLearning/NeuralNetworks/XOR_NeuralNetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense

# Define Training DATA i.e, XOR Gate Inputs
input = np.array([[0,0],[0,1],[1,0],[1,1]])
# Desired Output
output = np.array([[0],[1],[1],[0]])

# Model Definition
model = Sequential()
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='mean_squared_error',optimizer='adam', metrics=['binary_accuracy'])

# Train Model
model.fit(input, output, epochs=600, verbose=2)

# Validation
print("Round off Values: \n",model.predict(input).round())
print("Actual Values: \n",model.predict(input))
# Out:
# Epoch 1/600
# 1/1 - 14s - loss: 0.2727 - binary_accuracy: 0.5000
# Epoch 2/600
# 1/1 - 0s - loss: 0.2719 - binary_accuracy: 0.2500
# Epoch 3/600
# 1/1 - 0s - loss: 0.2710 - binary_accuracy: 0.2500
# Epoch 4/600
# 1/1 - 0s - loss: 0.2702 - binary_accuracy: 0.2500
# Epoch 5/600
# 1/1 - 0s - loss: 0.2693 - binary_accuracy: 0.2500
# Epoch 6/600
# 1/1 - 0s - loss: 0.2685 - binary_accuracy: 0.2500
# Epoch 7/600
# 1/1 - 0s - loss: 0.2676 - binary_accuracy: 0.2500
# Epoch 8/600
# 1/1 - 0s - loss: 0.2668 - binary_accuracy: 0.2500
# Epoch 9/600
# 1/1 - 0s - loss: 0.2660 - binary_accuracy: 0.2500
# Epoch 10/600
# 1/1 - 0s - loss: 0.2652 - binary_accuracy: 0.2500
# Epoch 11/600
# 1/1 - 0s - loss: 0.2644 - binary_accuracy: 0.2500
# Epoch 12/600
# 1/1 - 0s - loss: 0.2636 - binary_accuracy: 0.2500
# Epoch 13/600
# 1/1 - 0s - loss: 0.2628 - binary_accuracy: 0.2500
# Epoch 14/600
# 1/1 - 0s - loss: 0.2620 - binary_accuracy: 0.2500
# Epoch 15/600
# 1/1 - 0s - loss: 0.2613 - binary_accuracy: 0.2500
# ...
